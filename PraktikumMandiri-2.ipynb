# %%
import pandas as pd
import numpy as np
# import dataFrame
df = pd.read_csv('shopping_trends.csv')
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
# menghapus kolom yang tidak digunakan
del(df['Customer ID'],df['Age'],df['Size'],df['Color'],df['Season'],df['Review Rating'],df['Discount Applied'],df['Promo Code Used'],df['Preferred Payment Method'])
df
# Out:
#       Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0       Male         Blouse     Clothing                     53
# 1       Male        Sweater     Clothing                     64
# 2       Male          Jeans     Clothing                     73
# 3       Male        Sandals     Footwear                     90
# 4       Male         Blouse     Clothing                     49
# ...      ...            ...          ...                    ...
# 3895  Female         Hoodie     Clothing                     28
# 3896  Female       Backpack  Accessories                     49
# 3897  Female           Belt  Accessories                     33
# 3898  Female          Shoes     Footwear                     77
# 3899  Female        Handbag  Accessories                     81
#
#            Location Subscription Status Payment Method   Shipping Type  \
# 0          Kentucky                 Yes    Credit Card         Express
# ...

# %%
df.isnull().sum()
# Out:
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Subscription Status       0
# Payment Method            0
# Shipping Type             0
# Previous Purchases        0
# Frequency of Purchases    0
# dtype: int64

# %%
df['Purchase Amount (USD)'].mean()
# Out:
# np.float64(59.76435897435898)

# %%
df['Purchase Amount (USD)'].median()
# Out:
# np.float64(60.0)

# %%
df['Purchase Amount (USD)'].mode()
# Out:
# 0    32
# 1    36
# 2    94
# Name: Purchase Amount (USD), dtype: int64

# %%
import matplotlib.pyplot as plt

df.boxplot(column=['Purchase Amount (USD)','Previous Purchases'])
plt.show()

# %%
outlier_data = {
    'Gender': ["Male","Female","Female","Male"],
    'Item Purchased': ["Sweater","Sandals","Sweater","Sandals"],
    'Category': ["Clothing","Footwear","Clothing","Footwear"],
    'Purchase Amount (USD)': [60, 150, 72, 154],
    'Location': ["Jakrata", "Depok", "Bekasi", "Bogor"],
    'Subscription Status': ["Yes","Yes","Yes","Yes"],
    'Payment Method': ["Cash","Cash","Cash","Cash"],
    'Shipping Type': ["Express", "Express", "Express", "Express"],
    'Previous Purchases': [20, 85, 18, 89],
    'Frequency of Purchases': ["Weekly", "Weekly", "Weekly", "Weekly"]
}

outlier_df = pd.DataFrame(outlier_data)

df = pd.concat([df, outlier_df], ignore_index=True)
df
# Out:
#       Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0       Male         Blouse     Clothing                     53
# 1       Male        Sweater     Clothing                     64
# 2       Male          Jeans     Clothing                     73
# 3       Male        Sandals     Footwear                     90
# 4       Male         Blouse     Clothing                     49
# ...      ...            ...          ...                    ...
# 3899  Female        Handbag  Accessories                     81
# 3900    Male        Sweater     Clothing                     60
# 3901  Female        Sandals     Footwear                    150
# 3902  Female        Sweater     Clothing                     72
# 3903    Male        Sandals     Footwear                    154
#
#            Location Subscription Status Payment Method  Shipping Type  \
# 0          Kentucky                 Yes    Credit Card        Express
# ...

# %%
df.boxplot(column=['Purchase Amount (USD)','Previous Purchases'])
plt.title('Boxplot of Purchase Amount (USD) and Previous Purchases with Outliers')
plt.show()

# %%
# Hitung kuartil pertama (Q1)
q1 = df['Purchase Amount (USD)'].quantile(0.25)
print("Q1 : ", q1)
# Hitung kuartil ketiga (Q3)
q3 = df['Purchase Amount (USD)'].quantile(0.75)
print("Q3 : ", q3)
iqr = q3 - q1
# Hitung batas bawah (Lower Bound) dan batas atas (upper Bound) untuk Outlier
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# temukan outlier dalam DaraFrame
outliers = df[(df['Purchase Amount (USD)'] < lower_bound) | (df['Purchase Amount (USD)'] > upper_bound)]

print("Outlier Purchase Amount (USD): ")
print(outliers)
# mencari data outlier dalam kolom
# Out:
# Q1 :  39.0
# Q3 :  81.0
# Outlier Purchase Amount (USD):
#       Gender Item Purchased  Category  Purchase Amount (USD) Location  \
# 3901  Female        Sandals  Footwear                    150    Depok
# 3903    Male        Sandals  Footwear                    154    Bogor
#
#      Subscription Status Payment Method Shipping Type  Previous Purchases  \
# 3901                 Yes           Cash       Express                  85
# 3903                 Yes           Cash       Express                  89
#
#      Frequency of Purchases
# 3901                 Weekly
# 3903                 Weekly
